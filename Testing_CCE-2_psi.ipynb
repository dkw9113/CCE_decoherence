# %%
from IPython.display import HTML
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %% [markdown]
# Cut - nuclear dimers that are 1.5 nm from each NV center are removed from coherence simulation; $W_{12}$ - coherence from entangled pair; $W_1$ and $W_2$ coherence of each NV center (within S=1 but $m_s=\{0,1\}$ manifold).

# %%
from ipywidgets import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-2_dist_5_cpp_CUT1.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.linspace(0,140000,100)
#time1=np.linspace(0,10000,101)
#for i in range(1,3):
#    for j in range(len(b.loc[:,i])):
#        b.set_value(j,i,eval(b.loc[j,i]))
#for i in range(1,3):
#    for j in range(len(b.ix[:,i])):
#        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"const field NV-NV: $\Psi_{\pm}$, B=3,000 G, d = 5 nm - cut")
#plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
#plt.plot(time,b.ix[:,1],color="red",label=r"CCE-2 MC 1$\%$")
#plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)

cce2py=np.loadtxt("CCE-2_anal_pair_r_sph_30_NV_dist_5.00_mag_field3000.0Gs_cut.dat")

#plt.plot(b.ix[:,0],b.ix[:,1],color="green",label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,1],color="red", label=r"$W_{12}$")
plt.plot(b.ix[:,0],np.multiply(b.ix[:,2],b.ix[:,3]),ls="--",color="blue",label=r"$W_1\cdot W_2$")
#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")

#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")
plt.xlim([0,1400000])
plt.legend()

# %%
from ipywidgets import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-2_dist_10_cpp_CUT1.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.linspace(0,140000,100)
#time1=np.linspace(0,10000,101)
#for i in range(1,3):
#    for j in range(len(b.loc[:,i])):
#        b.set_value(j,i,eval(b.loc[j,i]))
#for i in range(1,3):
#    for j in range(len(b.ix[:,i])):
#        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"const field NV-NV: $\Psi_{\pm}$, B=3,000 G, d = 10 nm - cut")
#plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
#plt.plot(time,b.ix[:,1],color="red",label=r"CCE-2 MC 1$\%$")
#plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)

cce2py=np.loadtxt("CCE-2_anal_pair_r_sph_30_NV_dist_10.00_mag_field3000.0Gs_cut.dat")

#plt.plot(b.ix[:,0],b.ix[:,1],color="green",label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,1],color="red", label=r"$W_{12}$")
plt.plot(b.ix[:,0],np.multiply(b.ix[:,2],b.ix[:,3]),ls="--",color="blue",label=r"$W_1\cdot W_2$")
#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")

#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")
plt.xlim([0,1400000])
plt.legend()

# %%
from ipywidgets import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-2_dist_20_cpp_CUT1.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.linspace(0,140000,100)
#time1=np.linspace(0,10000,101)
#for i in range(1,3):
#    for j in range(len(b.loc[:,i])):
#        b.set_value(j,i,eval(b.loc[j,i]))
#for i in range(1,3):
#    for j in range(len(b.ix[:,i])):
#        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"const field NV-NV: $\Psi_{\pm}$, B=3,000 G, d = 20 nm - cut")
#plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
#plt.plot(time,b.ix[:,1],color="red",label=r"CCE-2 MC 1$\%$")
#plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)

cce2py=np.loadtxt("CCE-2_anal_pair_r_sph_30_NV_dist_20.00_mag_field3000.0Gs_cut.dat")

#plt.plot(b.ix[:,0],b.ix[:,1],color="green",label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,1],color="red", label=r"$W_{12}$")
plt.plot(b.ix[:,0],np.multiply(b.ix[:,2],b.ix[:,3]),ls="--",color="blue",label=r"$W_1\cdot W_2$")
#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")

#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")
plt.xlim([0,1400000])
plt.legend()

# %%
from ipywidgets import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-2_dist_5_cpp1.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.linspace(0,140000,100)
#time1=np.linspace(0,10000,101)
#for i in range(1,3):
#    for j in range(len(b.loc[:,i])):
#        b.set_value(j,i,eval(b.loc[j,i]))
#for i in range(1,3):
#    for j in range(len(b.ix[:,i])):
#        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"const field NV-NV: $\Psi_{\pm}$, B=3,000 G, d = 5 nm - no cut")
#plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
#plt.plot(time,b.ix[:,1],color="red",label=r"CCE-2 MC 1$\%$")
#plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)

cce2py=np.loadtxt("CCE-2_anal_pair_r_sph_30_NV_dist_5.00_mag_field3000.0Gs_nocut.dat")

#plt.plot(b.ix[:,0],b.ix[:,1],color="green",label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,1],color="red", label=r"$W_{12}$")
plt.plot(b.ix[:,0],np.multiply(b.ix[:,2],b.ix[:,3]),ls="--",color="blue",label=r"$W_1\cdot W_2$")
#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")

#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")
plt.xlim([0,1400000])
plt.legend()

# %%
from ipywidgets import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-2_dist_10_cpp1.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.linspace(0,140000,100)
#time1=np.linspace(0,10000,101)
#for i in range(1,3):
#    for j in range(len(b.loc[:,i])):
#        b.set_value(j,i,eval(b.loc[j,i]))
#for i in range(1,3):
#    for j in range(len(b.ix[:,i])):
#        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"const field NV-NV: $\Psi_{\pm}$, B=3,000 G, d = 10 nm - no cut")
#plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
#plt.plot(time,b.ix[:,1],color="red",label=r"CCE-2 MC 1$\%$")
#plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)

cce2py=np.loadtxt("CCE-2_anal_pair_r_sph_30_NV_dist_10.00_mag_field3000.0Gs_nocut.dat")

#plt.plot(b.ix[:,0],b.ix[:,1],color="green",label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,1],color="red", label=r"$W_{12}$")
plt.plot(b.ix[:,0],np.multiply(b.ix[:,2],b.ix[:,3]),ls="--",color="blue",label=r"$W_1\cdot W_2$")
#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")

#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")
plt.xlim([0,1400000])
plt.legend()

# %%
from ipywidgets import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-2_dist_20_cpp1.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.linspace(0,140000,100)
#time1=np.linspace(0,10000,101)
#for i in range(1,3):
#    for j in range(len(b.loc[:,i])):
#        b.set_value(j,i,eval(b.loc[j,i]))
#for i in range(1,3):
#    for j in range(len(b.ix[:,i])):
#        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"const field NV-NV: $\Psi_{\pm}$, B=3,000 G, d = 20 nm - no cut")
#plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
#plt.plot(time,b.ix[:,1],color="red",label=r"CCE-2 MC 1$\%$")
#plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)

cce2py=np.loadtxt("CCE-2_anal_pair_r_sph_30_NV_dist_20.00_mag_field3000.0Gs_cut.dat")

#plt.plot(b.ix[:,0],b.ix[:,1],color="green",label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,1],color="red", label=r"$W_{12}$")
plt.plot(b.ix[:,0],np.multiply(b.ix[:,2],b.ix[:,3]),ls="--",color="blue",label=r"$W_1\cdot W_2$")
#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")

#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")
plt.xlim([0,1400000])
plt.legend()

# %%
from ipywidgets import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-2_dist_20_cpp1_grad.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.linspace(0,140000,100)
#time1=np.linspace(0,10000,101)
#for i in range(1,3):
#    for j in range(len(b.loc[:,i])):
#        b.set_value(j,i,eval(b.loc[j,i]))
#for i in range(1,3):
#    for j in range(len(b.ix[:,i])):
#        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"GRADIENT, NV-NV: $\Psi_{\pm}$, B=3,000 G, d = 20 nm - no cut")
#plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
#plt.plot(time,b.ix[:,1],color="red",label=r"CCE-2 MC 1$\%$")
#plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)

cce2py=np.loadtxt("CCE-2_anal_pair_r_sph_30_NV_dist_20.00_mag_field3000.0Gs_nocut.dat")

#plt.plot(b.ix[:,0],b.ix[:,1],color="green",label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,1],color="red", label=r"$W_{12}$")
plt.plot(b.ix[:,0],np.multiply(b.ix[:,2],b.ix[:,3]),ls="--",color="blue",label=r"$W_1\cdot W_2$")
#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")

plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")
#plt.xlim([0,1400000])
plt.legend()

# %%
from ipywidgets import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-2_dist_10_cpp1_grad.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.linspace(0,140000,100)
#time1=np.linspace(0,10000,101)
#for i in range(1,3):
#    for j in range(len(b.loc[:,i])):
#        b.set_value(j,i,eval(b.loc[j,i]))
#for i in range(1,3):
#    for j in range(len(b.ix[:,i])):
#        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"GRADIENT, NV-NV: $\Psi_{\pm}$, B=3,000 G, d = 10 nm - no cut")
#plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
#plt.plot(time,b.ix[:,1],color="red",label=r"CCE-2 MC 1$\%$")
#plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)

cce2py=np.loadtxt("CCE-2_anal_pair_r_sph_30_NV_dist_10.00_mag_field3000.0Gs_nocut.dat")

#plt.plot(b.ix[:,0],b.ix[:,1],color="green",label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,1],color="red", label=r"$W_{12}$")
plt.plot(b.ix[:,0],np.multiply(b.ix[:,2],b.ix[:,3]),ls="--",color="blue",label=r"$W_1\cdot W_2$")
#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")

plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")
#plt.xlim([0,1400000])
plt.legend()

# %%
from ipywidgets import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-2_dist_5_cpp1_grad.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.linspace(0,140000,100)
#time1=np.linspace(0,10000,101)
#for i in range(1,3):
#    for j in range(len(b.loc[:,i])):
#        b.set_value(j,i,eval(b.loc[j,i]))
#for i in range(1,3):
#    for j in range(len(b.ix[:,i])):
#        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"GRADIENT NV-NV: $\Psi_{\pm}$, B=3,000 G, d = 5 nm - no cut")
#plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
#plt.plot(time,b.ix[:,1],color="red",label=r"CCE-2 MC 1$\%$")
#plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)

cce2py=np.loadtxt("CCE-2_anal_pair_r_sph_30_NV_dist_5.00_mag_field3000.0Gs_nocut.dat")

#plt.plot(b.ix[:,0],b.ix[:,1],color="green",label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,1],color="red", label=r"$W_{12}$")
plt.plot(b.ix[:,0],np.multiply(b.ix[:,2],b.ix[:,3]),ls="--",color="blue",label=r"$W_1\cdot W_2$")
#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")

plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")
#plt.xlim([0,1400000])
plt.legend()

# %%
from ipywidgets import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-2_dist_20_cpp1_grad_cut.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.linspace(0,140000,100)
#time1=np.linspace(0,10000,101)
#for i in range(1,3):
#    for j in range(len(b.loc[:,i])):
#        b.set_value(j,i,eval(b.loc[j,i]))
#for i in range(1,3):
#    for j in range(len(b.ix[:,i])):
#        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"GRADIENT, NV-NV: $\Psi_{\pm}$, B=3,000 G, d = 20 nm - cut")
#plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
#plt.plot(time,b.ix[:,1],color="red",label=r"CCE-2 MC 1$\%$")
#plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)

cce2py=np.loadtxt("CCE-2_anal_pair_r_sph_30_NV_dist_20.00_mag_field3000.0Gs_cut.dat")

#plt.plot(b.ix[:,0],b.ix[:,1],color="green",label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,1],color="red", label=r"$W_{12}$")
plt.plot(b.ix[:,0],np.multiply(b.ix[:,2],b.ix[:,3]),ls="--",color="blue",label=r"$W_1\cdot W_2$")
#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")

plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")
#plt.xlim([0,1400000])
plt.legend()

# %%
from ipywidgets import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-2_dist_10_cpp1_grad_cut.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.linspace(0,140000,100)
#time1=np.linspace(0,10000,101)
#for i in range(1,3):
#    for j in range(len(b.loc[:,i])):
#        b.set_value(j,i,eval(b.loc[j,i]))
#for i in range(1,3):
#    for j in range(len(b.ix[:,i])):
#        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"GRADIENT, NV-NV: $\Psi_{\pm}$, B=3,000 G, d = 10 nm -  cut")
#plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
#plt.plot(time,b.ix[:,1],color="red",label=r"CCE-2 MC 1$\%$")
#plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)

cce2py=np.loadtxt("CCE-2_anal_pair_r_sph_30_NV_dist_10.00_mag_field3000.0Gs_cut.dat")

#plt.plot(b.ix[:,0],b.ix[:,1],color="green",label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,1],color="red", label=r"$W_{12}$")
plt.plot(b.ix[:,0],np.multiply(b.ix[:,2],b.ix[:,3]),ls="--",color="blue",label=r"$W_1\cdot W_2$")
#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")

plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")
#plt.xlim([0,1400000])
plt.legend()

# %%
from ipywidgets import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-2_dist_5_cpp1_grad_cut.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.linspace(0,140000,100)
#time1=np.linspace(0,10000,101)
#for i in range(1,3):
#    for j in range(len(b.loc[:,i])):
#        b.set_value(j,i,eval(b.loc[j,i]))
#for i in range(1,3):
#    for j in range(len(b.ix[:,i])):
#        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"GRADIENT NV-NV: $\Psi_{\pm}$, B=3,000 G, d = 5 nm - cut")
#plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
#plt.plot(time,b.ix[:,1],color="red",label=r"CCE-2 MC 1$\%$")
#plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)

cce2py=np.loadtxt("CCE-2_anal_pair_r_sph_30_NV_dist_5.00_mag_field3000.0Gs_cut.dat")

#plt.plot(b.ix[:,0],b.ix[:,1],color="green",label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,1],color="red", label=r"$W_{12}$")
plt.plot(b.ix[:,0],np.multiply(b.ix[:,2],b.ix[:,3]),ls="--",color="blue",label=r"$W_1\cdot W_2$")
#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")

plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")
#plt.xlim([0,1400000])
plt.legend()

# %% [markdown]
# Including anisotropic terms in hf-interaction...

# %%
import numpy as np
grad=np.loadtxt("omega_grad_pioro.dat")
plt.hist(grad,bins=100)
plt.show()

# %%
from ipywidgets import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-2_aniso_result_3000_nograd_3000T.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.linspace(0,250000,300)
#time1=np.linspace(0,10000,101)
for i in range(1,3):
    for j in range(len(b.loc[:,i])):
        b.set_value(j,i,eval(b.loc[j,i]))
for i in range(1,3):
    for j in range(len(b.ix[:,i])):
        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"ANISOTROPY & NO GRADIENT NV-NV: $\Psi_{\pm}$, B=3,000 G, d = 20 nm - no cut")
#plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
#plt.plot(time,b.ix[:,1],color="red",label=r"CCE-2 MC 1$\%$")
#plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)

cce2py=np.loadtxt("CCE-2_anal_pair_r_sph_30_NV_dist_5.00_mag_field3000.0Gs_nocut.dat")

plt.plot(b.ix[:,0],b.ix[:,1],color="green",label="CCE-1")
#plt.plot(b.ix[:,0],b.ix[:,1],color="red", label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,2],color="blue",label="CCE-2")
plt.plot(b.ix[:,0],b.ix[:,3],color="cyan",label=R"$W_{12}$")
plt.plot(b.ix[:,0],np.multiply(b.ix[:,4],b.ix[:,5]),ls="--",color="magenta",label=r"$W_1\cdot W_2$")
#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")

#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")
plt.xlim([0,500000])
plt.legend()

# %%
from ipywidgets import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-2_aniso_result_3000_correct_20_1.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.linspace(0,250000,300)
#time1=np.linspace(0,10000,101)
for i in range(1,3):
    for j in range(len(b.loc[:,i])):
        b.set_value(j,i,eval(b.loc[j,i]))
for i in range(1,3):
    for j in range(len(b.ix[:,i])):
        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"ANISOTROPY & GRADIENT NV-NV: $\Psi_{\pm}$, B=3,000 G, d = 20 nm - no cut")
#plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
#plt.plot(time,b.ix[:,1],color="red",label=r"CCE-2 MC 1$\%$")
#plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)

cce2py=np.loadtxt("CCE-2_anal_pair_r_sph_30_NV_dist_5.00_mag_field3000.0Gs_nocut.dat")

#plt.plot(b.ix[:,0],b.ix[:,1],color="green",label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,1],color="red", label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,2],color="blue",label="CCE-2")
plt.plot(b.ix[:,0],b.ix[:,3],color="cyan",label=R"$W_{12}$")
plt.plot(b.ix[:,0],np.multiply(b.ix[:,4],b.ix[:,5]),ls="--",color="magenta",label=r"$W_1\cdot W_2$")
#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")

#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")
plt.xlim([0,500000])
plt.legend()

# %%
from ipywidgets import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-2_aniso_result_3000_correct_10_1.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.linspace(0,250000,300)
#time1=np.linspace(0,10000,101)
for i in range(1,3):
    for j in range(len(b.loc[:,i])):
        b.set_value(j,i,eval(b.loc[j,i]))
for i in range(1,3):
    for j in range(len(b.ix[:,i])):
        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"ANISOTROPY & GRADIENT NV-NV: $\Psi_{\pm}$, B=3,000 G, d = 10 nm - no cut")
#plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
#plt.plot(time,b.ix[:,1],color="red",label=r"CCE-2 MC 1$\%$")
#plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)

cce2py=np.loadtxt("CCE-2_anal_pair_r_sph_30_NV_dist_5.00_mag_field3000.0Gs_nocut.dat")

#plt.plot(b.ix[:,0],b.ix[:,1],color="green",label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,1],color="red", label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,2],color="blue",label="CCE-2")
plt.plot(b.ix[:,0],b.ix[:,3],color="cyan",label=R"$W_{12}$")
plt.plot(b.ix[:,0],np.multiply(b.ix[:,4],b.ix[:,5]),ls="--",color="magenta",label=r"$W_1\cdot W_2$")
#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")

#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")
plt.xlim([0,500000])
plt.legend()

# %%
from ipywidgets import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-2_aniso_result_3000_correct_5_1.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.linspace(0,250000,300)
#time1=np.linspace(0,10000,101)
for i in range(1,3):
    for j in range(len(b.loc[:,i])):
        b.set_value(j,i,eval(b.loc[j,i]))
for i in range(1,3):
    for j in range(len(b.ix[:,i])):
        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"ANISOTROPY & GRADIENT NV-NV: $\Psi_{\pm}$, B=3,000 G, d = 5 nm - no cut")
#plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
#plt.plot(time,b.ix[:,1],color="red",label=r"CCE-2 MC 1$\%$")
#plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)

cce2py=np.loadtxt("CCE-2_anal_pair_r_sph_30_NV_dist_5.00_mag_field3000.0Gs_nocut.dat")

#plt.plot(b.ix[:,0],b.ix[:,1],color="green",label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,1],color="red", label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,2],color="blue",label="CCE-2")
plt.plot(b.ix[:,0],b.ix[:,3],color="cyan",label=R"$W_{12}$")
plt.plot(b.ix[:,0],np.multiply(b.ix[:,4],b.ix[:,5]),ls="--",color="magenta",label=r"$W_1\cdot W_2$")
#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")

#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")
plt.xlim([0,500000])
plt.legend()

# %%
from ipywidgets import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-3_noaniso_result.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.linspace(0,250000,300)
#time1=np.linspace(0,10000,101)
for i in range(1,4):
    for j in range(len(b.loc[:,i])):
        b.set_value(j,i,eval(b.loc[j,i]))
for i in range(1,4):
    for j in range(len(b.ix[:,i])):
        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"GRADIENT NV-NV: $\Psi_{\pm}$, B=3,000 G, d = 20 nm - no cut")
#plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
#plt.plot(time,b.ix[:,1],color="red",label=r"CCE-2 MC 1$\%$")
#plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)

cce2py=np.loadtxt("CCE-2_anal_pair_r_sph_30_NV_dist_20.00_mag_field3000.0Gs_nocut.dat")

#plt.plot(b.ix[:,0],b.ix[:,1],color="green",label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,1],color="red", label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,2],color="blue",label="CCE-2")
plt.plot(b.ix[:,0],b.ix[:,3],color="yellow",ls="--",label="CCE-3")
plt.plot(b.ix[:,0],b.ix[:,4],color="cyan",label=R"$W_{12}$")
plt.plot(b.ix[:,0],np.multiply(b.ix[:,5],b.ix[:,6]),ls="--",color="magenta",label=r"$W_1\cdot W_2$")
#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")

#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")
plt.xlim([0,500000])
plt.legend()

# %%
from ipywidgets import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-3_aniso_result_20.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.linspace(0,250000,300)
#time1=np.linspace(0,10000,101)
for i in range(1,4):
    for j in range(len(b.loc[:,i])):
        b.set_value(j,i,eval(b.loc[j,i]))
for i in range(1,4):
    for j in range(len(b.ix[:,i])):
        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"GRADIENT NV-NV: $\Psi_{\pm}$, B=3,000 G, d = 20 nm - no cut")
#plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
#plt.plot(time,b.ix[:,1],color="red",label=r"CCE-2 MC 1$\%$")
#plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)

cce2py=np.loadtxt("CCE-2_anal_pair_r_sph_30_NV_dist_20.00_mag_field3000.0Gs_nocut.dat")

#plt.plot(b.ix[:,0],b.ix[:,1],color="green",label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,1],color="red", label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,2],color="blue",label="CCE-2")
plt.plot(b.ix[:,0],b.ix[:,3],color="yellow",ls="--",label="CCE-3")
plt.plot(b.ix[:,0],b.ix[:,4],color="cyan",label=R"$W_{12}$")
plt.plot(b.ix[:,0],np.multiply(b.ix[:,5],b.ix[:,6]),ls="--",color="magenta",label=r"$W_1\cdot W_2$")
#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")

#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")
plt.xlim([0,500000])
plt.legend()

# %%
from ipywidgets import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-4_result_20.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.linspace(0,250000,300)
#time1=np.linspace(0,10000,101)
for i in range(1,5):
    for j in range(len(b.loc[:,i])):
        b.set_value(j,i,eval(b.loc[j,i]))
for i in range(1,5):
    for j in range(len(b.ix[:,i])):
        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"GRADIENT NV-NV: $\Psi_{\pm}$, B=3,000 G, d = 20 nm - no cut")
#plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
#plt.plot(time,b.ix[:,1],color="red",label=r"CCE-2 MC 1$\%$")
#plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)

cce2py=np.loadtxt("CCE-2_anal_pair_r_sph_30_NV_dist_20.00_mag_field3000.0Gs_nocut.dat")

#plt.plot(b.ix[:,0],b.ix[:,1],color="green",label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,1],color="red", label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,2],color="blue",label="CCE-2")
plt.plot(b.ix[:,0],b.ix[:,3],color="yellow",ls="--",label="CCE-3")
plt.plot(b.ix[:,0],b.ix[:,4],color="black",ls="--",label="CCE-4")
plt.plot(b.ix[:,0],b.ix[:,5],color="cyan",ls="--",label=R"$W_{12}$")
plt.plot(b.ix[:,0],np.multiply(b.ix[:,6],b.ix[:,7]),ls="--",color="magenta",label=r"$W_1\cdot W_2$")
#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")

#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")
plt.xlim([0,500000])
plt.legend()

# %%
from ipywidgets import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-4_aniso_result.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.linspace(0,250000,300)
#time1=np.linspace(0,10000,101)
#for i in range(1,4):
#    for j in range(len(b.loc[:,i])):
#        b.set_value(j,i,eval(b.loc[j,i]))
#for i in range(1,4):
#    for j in range(len(b.ix[:,i])):
#        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"GRADIENT NV-NV: $\Psi_{\pm}$, B=3,000 G, d = 20 nm - no cut")
#plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
#plt.plot(time,b.ix[:,1],color="red",label=r"CCE-2 MC 1$\%$")
#plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)

cce2py=np.loadtxt("CCE-2_anal_pair_r_sph_30_NV_dist_20.00_mag_field3000.0Gs_nocut.dat")

#plt.plot(b.ix[:,0],b.ix[:,1],color="green",label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,1],color="red", label="CCE-1")
plt.plot(b.ix[:,0],b.ix[:,2],color="blue",label="CCE-2")
plt.plot(b.ix[:,0],b.ix[:,3],color="yellow",ls="--",label="CCE-3")
plt.plot(b.ix[:,0],b.ix[:,4],color="black", ls="--",label="CCE-4")
plt.plot(b.ix[:,0],b.ix[:,5],color="cyan",label=R"$W_{12}$")
plt.plot(b.ix[:,0],np.multiply(b.ix[:,6],b.ix[:,7]),ls="--",color="magenta",label=r"$W_1\cdot W_2$")
#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")

#plt.plot(cce2py[:,0],cce2py[:,1],color="magenta",label="CCE-2 an Python")
plt.xlim([0,500000])
plt.legend()
