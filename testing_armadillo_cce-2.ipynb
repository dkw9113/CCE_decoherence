# %% [markdown]
# Currently there is 1-to-1 relation between matrixExp and analytic results using the code in C++, but...
# Python gives different shape...

# %%
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
result=np.loadtxt("results.dat")
nohbar_py=np.loadtxt("Wan_result_PY_nohbar.dat")
plt.plot(result[:,0],result[:,1],'b',label="C++")
plt.plot(result[:,0],result[:,2],'r--',label="Python")
plt.plot(nohbar_py[:,0],nohbar_py[:,1],'g--',label="Python-nohbar")
plt.legend()
plt.show()
