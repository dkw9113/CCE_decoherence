# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-3_noaniso_result1.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.loadtxt("Wan_result_PY.dat")[:,0]
for i in range(3):
    for j in range(len(b.loc[:,i])):
        b.set_value(j,i,eval(b.loc[j,i]))
for i in range(3):
    for j in range(len(b.ix[:,i])):
        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title("B= 3000 G. Aniso not included. $\mathcal{R}=3a_0$")
plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
plt.plot(time,b.ix[:,1],color="red",label="CCE-2")
plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)
plt.legend()
#plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-3_noaniso_result_4a0.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.loadtxt("Wan_result_PY.dat")[:,0]
for i in range(3):
    for j in range(len(b.loc[:,i])):
        b.set_value(j,i,eval(b.loc[j,i]))
for i in range(3):
    for j in range(len(b.ix[:,i])):
        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title("B= 3000 G. Aniso not included.$\mathcal{R}=4a_0$")
plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
plt.plot(time,b.ix[:,1],color="red",label="CCE-2")
plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)
plt.legend()
#plt.show()
a1="cce-3_noaniso_result1.dat"
b1=pd.read_csv(a1,delimiter="\t",header=None)
time=np.loadtxt("Wan_result_PY.dat")[:,0]
for i in range(3):
    for j in range(len(b1.loc[:,i])):
        b1.set_value(j,i,eval(b1.loc[j,i]))
for i in range(3):
    for j in range(len(b1.ix[:,i])):
        b1.set_value(j,i,abs(complex(b1.ix[j,i][0],b1.ix[j,i][1])))
#plt.plot(time,b.ix[:,2]-b1.ix[:,2],'r--',label="3a0-4a0")
#plt.ylim(-0.001,0.001)

# %%
a="cce-3_noaniso_result_4a0.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.loadtxt("Wan_result_PY.dat")[:,0]
for i in range(3):
    for j in range(len(b.loc[:,i])):
        b.set_value(j,i,eval(b.loc[j,i]))
for i in range(3):
    for j in range(len(b.ix[:,i])):
        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
a1="cce-3_noaniso_result1.dat"
b1=pd.read_csv(a1,delimiter="\t",header=None)
time=np.loadtxt("Wan_result_PY.dat")[:,0]
for i in range(3):
    for j in range(len(b1.loc[:,i])):
        b1.set_value(j,i,eval(b1.loc[j,i]))
for i in range(3):
    for j in range(len(b1.ix[:,i])):
        b1.set_value(j,i,abs(complex(b1.ix[j,i][0],b1.ix[j,i][1])))
plt.plot(time,b.ix[:,2]-b1.ix[:,2],'r--',label="3a0-4a0")
plt.ylim(-0.01,0.001)
# Out:
# (-0.01, 0.001)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-3_noaniso_result_5a0.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.loadtxt("Wan_result_PY.dat")[:,0]
for i in range(3):
    for j in range(len(b.loc[:,i])):
        b.set_value(j,i,eval(b.loc[j,i]))
for i in range(3):
    for j in range(len(b.ix[:,i])):
        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title("B= 3000 G. Aniso not included. $\mathcal{R}=5a_0$")
plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
plt.plot(time,b.ix[:,1],color="red",label="CCE-2")
plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)
plt.legend()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-3_noaniso_result_7a0.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
print(len(b.ix[:,0]))
time=np.loadtxt("Wan_result_PY.dat")[::10,0]
for i in range(3):
    for j in range(len(b.loc[:,i])):
        b.set_value(j,i,eval(b.loc[j,i]))
for i in range(3):
    for j in range(len(b.ix[:,i])):
        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title("B= 3000 G. Aniso not included. $\mathcal{R}=7a_0$")
plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
plt.plot(time,b.ix[:,1],color="red",label="CCE-2")
plt.plot(time,b.ix[:,2],color="blue",ls="--",label="CCE-3")
#plt.plot(time,b.ix[:,3],color="magenta",label="CCE-2 anal")
plt.ylim(-0.1,1.1)
plt.legend()
# Out:
# 10

# %%
aniso=np.loadtxt("cce-3_result_aniso_50.dat")
plt.title("B = 50 G. Aniso included.")
plt.plot(aniso[:,0],aniso[:,1],color="green",label="CCE-1")

"""for i in range(len(aniso[:,3])):
    if aniso[i,2]>aniso[i,4]:
        aniso[i,2]=aniso[i,4]"""
plt.plot(aniso[:,0],aniso[:,2],color="magenta",label="CCE-2")
#for i in range(len(aniso[:,3])):
#    if aniso[i,3]>aniso[i,4]:
#        aniso[i,3]=aniso[i,4]
plt.plot(aniso[:,0],aniso[:,3],color="cyan",ls="--",label="CCE-3")
plt.plot(aniso[:,0],aniso[:,4],color="blue",ls="--",label="CCE-2 anal")
#plt.ylim(-0.1,1.1)
#print(aniso[:,3])
plt.legend()

# %%
aniso=np.loadtxt("cce-3_aniso_result_100.dat")
plt.title("B = 100 G. Aniso included.")
plt.plot(aniso[:,0],aniso[:,1],color="green",label="CCE-1")

for i in range(len(aniso[:,3])):
    if aniso[i,2]>aniso[i,4]:
        aniso[i,2]=aniso[i,4]
plt.plot(aniso[:,0],aniso[:,2],color="magenta",label="CCE-2")
#for i in range(len(aniso[:,3])):
#    if aniso[i,3]>aniso[i,4]:
#        aniso[i,3]=aniso[i,4]
plt.plot(aniso[:,0],aniso[:,3],color="cyan",ls="--",label="CCE-3")
plt.plot(aniso[:,0],aniso[:,4],color="blue",ls="--",label="CCE-2 anal")
#plt.ylim(-0.1,1.1)
#print(aniso[:,3])
plt.legend()

# %%
aniso=np.loadtxt("cce-3_aniso_result_100_small_tol.dat")
plt.title("B = 100 G. Aniso included.")
plt.plot(aniso[:,0],aniso[:,1],color="green",label="CCE-1")

for i in range(len(aniso[:,3])):
    if aniso[i,2]>aniso[i,4]:
        aniso[i,2]=aniso[i,4]
plt.plot(aniso[:,0],aniso[:,2],color="magenta",label="CCE-2")
#for i in range(len(aniso[:,3])):
#    if aniso[i,3]>aniso[i,4]:
#        aniso[i,3]=aniso[i,4]
plt.plot(aniso[:,0],aniso[:,3],color="cyan",ls="--",label="CCE-3")
plt.plot(aniso[:,0],aniso[:,4],color="blue",ls="--",label="CCE-2 anal")
#plt.ylim(-0.1,1.1)
#print(aniso[:,3])
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
aniso=np.loadtxt("cce-3_aniso_result_3000.dat")
plt.title("B = 3000 G. Aniso included.")
plt.plot(aniso[:,0],aniso[:,1],color="green",label="CCE-1")

for i in range(len(aniso[:,3])):
    if aniso[i,2]>aniso[i,4]:
        aniso[i,2]=aniso[i,4]
plt.plot(aniso[:,0],aniso[:,2],color="magenta",label="CCE-2")
for i in range(len(aniso[:,3])):
    if aniso[i,3]>aniso[i,4]:
        aniso[i,3]=aniso[i,4]
plt.plot(aniso[:,0],aniso[:,3],color="cyan",ls="--",label="CCE-3")
plt.plot(aniso[:,0],aniso[:,4],color="blue",ls="--",label="CCE-2 anal")
plt.ylim(-0.1,1.1)
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
aniso=np.loadtxt("cce-3_aniso_result_03_new.dat")
plt.title("B = 0.3 G. Aniso included.")
plt.plot(aniso[:,0],aniso[:,1],color="green",label="CCE-1")

#for i in range(len(aniso[:,3])):
#    if aniso[i,2]>aniso[i,4]:
#        aniso[i,2]=aniso[i,4]
plt.plot(aniso[:,0],aniso[:,2],color="magenta",label="CCE-2")
#for i in range(len(aniso[:,3])):
#    if aniso[i,3]>aniso[i,4]:
#        aniso[i,3]=aniso[i,4]
plt.plot(aniso[:,0],aniso[:,3],color="cyan",ls="--",label="CCE-3")
plt.plot(aniso[:,0],aniso[:,4],color="blue",ls="--",label="CCE-2 anal")
plt.ylim(-0.1,1.1)
plt.legend()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-3_noaniso_3000.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=np.loadtxt("Wan_result_PY.dat")[:,0]
for i in range(3):
    for j in range(len(b.loc[:,i])):
        b.set_value(j,i,eval(b.loc[j,i]))
for i in range(3):
    for j in range(len(b.ix[:,i])):
        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title("B= 3000 G. Aniso not included.")
plt.plot(time,b.ix[:,0],color="green",label="CCE-1")
plt.plot(time,b.ix[:,1],color="red",label="CCE-2")
plt.plot(time,b.ix[:,2],color="blue",label="CCE-3")
#plt.plot(time,np.multiply(b.ix[:,2],b.ix[:,3]), color="magenta",label="CCE-4")
#plt.plot(time,b.ix[:,3],color="cyan",label="CCE-2 an")
plt.ylim(-0.1,1.1)
plt.legend()
#plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-4_results_2a0.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=b.ix[:,0]
for i in range(1,5):
    for j in range(len(b.loc[:,i])):
        b.set_value(j,i,eval(b.loc[j,i]))
for i in range(1,5):
    for j in range(len(b.ix[:,i])):
        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"B= 3000 G. Aniso not included. $\mathcal{R}=2a_0$")
plt.plot(time,b.ix[:,1],color="green",label="CCE-1")
plt.plot(time,b.ix[:,2],color="red",label="CCE-2")
plt.plot(time,b.ix[:,3],color="blue",label="CCE-3")
plt.plot(time,b.ix[:,4], color="magenta",label="CCE-4")
plt.plot(time,b.ix[:,5],color="cyan",label="CCE-2 an")
plt.ylim(-0.1,1.1)
plt.legend()
#plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-4_results_3a0.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=b.ix[:,0]
for i in range(1,5):
    for j in range(len(b.loc[:,i])):
        b.set_value(j,i,eval(b.loc[j,i]))
for i in range(1,5):
    for j in range(len(b.ix[:,i])):
        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"B= 3000 G. Aniso not included. $\mathcal{R}=3a_0$")
plt.plot(time,b.ix[:,1],color="green",label="CCE-1")
plt.plot(time,b.ix[:,2],color="red",label="CCE-2")
plt.plot(time,b.ix[:,3],color="blue",label="CCE-3")
plt.plot(time,b.ix[:,4], color="magenta",label="CCE-4")
plt.plot(time,b.ix[:,5],color="cyan",label="CCE-2 an")
plt.ylim(-0.1,1.1)
plt.legend()
#plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-4_results_15a0.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=b.ix[:,0]
for i in range(1,5):
    for j in range(len(b.loc[:,i])):
        b.set_value(j,i,eval(b.loc[j,i]))
for i in range(1,5):
    for j in range(len(b.ix[:,i])):
        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"B= 3000 G. Aniso not included. $\mathcal{R}=1.5a_0$")
plt.plot(time,b.ix[:,1],color="green",label="CCE-1")
plt.plot(time,b.ix[:,2],color="red",label="CCE-2")
plt.plot(time,b.ix[:,3],color="blue",label="CCE-3")
plt.plot(time,b.ix[:,4], color="magenta",label="CCE-4")
plt.plot(time,b.ix[:,5],color="cyan",label="CCE-2 an")
plt.ylim(-0.1,1.1)
plt.legend()
print(b.ix[:,4]-b.ix[:,3])
#plt.show()
# Out:
# 0               0
# 1          -2e-06
# 2        -3.5e-05
# 3       -0.000163
# 4        -0.00048
# 5       -0.001059
# 6       -0.001885
# 7       -0.002867
# 8        -0.00382
# 9       -0.004581
# 10       -0.00517
# 11      -0.005551
# 12      -0.005668
# 13      -0.005636
# 14      -0.005546
# 15      -0.005484
# 16      -0.005615
# 17      -0.005973
# 18      -0.006483
# 19      -0.007131
# 20      -0.007882
# 21       -0.00867
# 22      -0.009523
# 23      -0.010389
# 24      -0.011076
# 25       -0.01145
# 26      -0.011499
# 27      -0.011324
# 28      -0.011081
# 29      -0.010829
#          ...
# 70    -2.5149e-05
# 71   -2.09008e-05
# 72   -1.73767e-05
# 73   -1.45115e-05
# 74   -1.22534e-05
# 75   -1.04266e-05
# 76   -8.95678e-06
# 77    -7.7455e-06
# 78    -6.6923e-06
# 79   -5.80432e-06
# 80   -5.10819e-06
# 81   -4.59064e-06
# 82   -4.20441e-06
# 83   -3.87873e-06
# 84   -3.56821e-06
# 85   -3.25878e-06
# 86   -2.95617e-06
# 87   -2.68867e-06
# 88   -2.44996e-06
# 89   -2.19995e-06
# 90   -1.93785e-06
# 91   -1.68065e-06
# 92   -1.44001e-06
# 93   -1.24681e-06
# 94   -1.10842e-06
# 95     -9.973e-07
# 96   -9.03883e-07
# 97   -8.28508e-07
# 98   -7.60649e-07
# 99   -7.05867e-07
# dtype: object

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-4_results_cutoff_08.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=b.ix[:,0]
for i in range(1,5):
    for j in range(len(b.loc[:,i])):
        b.set_value(j,i,eval(b.loc[j,i]))
for i in range(1,5):
    for j in range(len(b.ix[:,i])):
        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])
plt.title(r"B= 3000 G. Aniso not included. $\mathcal{R}=8 \AA$")
plt.plot(time,b.ix[:,1],color="green",label="CCE-1")
plt.plot(time,b.ix[:,2],color="red",label="CCE-2")
plt.plot(time,b.ix[:,3],color="blue",label="CCE-3")
plt.plot(time,b.ix[:,4], color="magenta",label="CCE-4")
plt.plot(time,b.ix[:,5],color="cyan",label="CCE-2 an")
plt.ylim(-0.1,1.1)
plt.legend()
#print(b.ix[:,4]-b.ix[:,3])
#plt.show()

# %% [markdown]
# Code for NV centers without anisotropic hf works fine. Move to CCE-4 with anisotropy and then QDs!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
a="cce-4_aniso_results_3000.dat"
b=pd.read_csv(a,delimiter="\t",header=None)
time=b.ix[:,0]
"""for i in range(1,5):
    for j in range(len(b.loc[:,i])):
        b.set_value(j,i,eval(b.loc[j,i]))
for i in range(1,5):
    for j in range(len(b.ix[:,i])):
        b.set_value(j,i,abs(complex(b.ix[j,i][0],b.ix[j,i][1])))
    #print(b.ix[:,i])"""
plt.title(r"B= 3000 G. Aniso included. $\mathcal{R}=8 \AA$")
plt.plot(time,b.ix[:,1],color="green",label="CCE-1")
plt.plot(time,b.ix[:,2],color="red",label="CCE-2")
plt.plot(time,b.ix[:,3],color="blue",label="CCE-3")
plt.plot(time,b.ix[:,4], color="magenta",label="CCE-4")
plt.plot(time,b.ix[:,5],color="cyan",label="CCE-2 an")
plt.ylim(-0.1,1.1)
plt.legend()
for i in range(len(b.ix[:,3])):
    if b.ix[i,3]-b.ix[i,4]!=0:
        print(b.ix[i,3]-b.ix[i,4])
#plt.show()
# Out:
# 0.001823
# -0.002245
# -0.002771
# -0.001429
# -0.001032
# -0.000523
# 0.00027
# -0.000704
# 0.002824
# 0.003748
# 0.003158
# 0.006265
# 0.005813
# 0.006144
# 0.009305
# 0.007618
# 0.008486
# 0.01005
# 0.008792
# 0.009349
# 0.010065
# 0.007234
# 0.007435
# 0.007147
# 0.005857
# 0.005692
# 0.0053
# 0.005588
# 0.005818
# 0.005804
# 0.00562
# 0.005639
# 0.005305
# 0.005172
# 0.004045
# 0.003977
# 0.003551
# 0.003083
# 0.003153
# 0.003775
# 0.003846
# 0.003924
# 0.003719
# 0.002576
# 0.001697
# 0.001646
# 0.001909
# 0.002076
# 0.002055
# 0.001725
# 0.001538
# 0.001708
# 0.002355
# 0.001819
# 0.001871
# 0.001898
# 0.00178
# 0.001827
# 0.001893
# 0.00167
# 0.001648
# 0.0016
# 0.001611
# 0.001215
# 0.001068
# 0.000858
# 0.000897
# 0.0008
# 0.000597
# 0.000359
# 0.0004
# 0.000384
# 0.000237
# 0.000268
# 0.000216
# 0.000215
# 0.000242
# 0.000177
# 0.000162
# 0.000145
# 0.0001179
# 0.0001009
# 0.0001079
# 0.0001067
# 0.0001161
# 0.0001048
# 9.96e-05
# 9.84e-05
# 8.49e-05
# 6.15e-05
# 6.02e-05
# 6.41e-05
# 5.67e-05
# 5.51e-05
# 4.83e-05
# 3.24e-05
# 2.87e-05
# 2.65e-05
# 1.76e-05
# 1.52e-05
